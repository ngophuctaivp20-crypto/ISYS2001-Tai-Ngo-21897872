# %% [markdown]
# <a href="https://colab.research.google.com/github/ngophuctaivp20-crypto/ISYS2001-Tai-Ngo-21897872/blob/main/Module%2001_hello_python__your_first_steps_in_coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print()

print("""My name is Tai.
I'm studying at Curtin.""")
print("I'm studying at Curtin University.\nMajoring in International Business and Logistics & Supply Chain Management.")
# Out:
# hello
#
# My name is Tai.
# I'm studying at Curtin.
# I'm studying at Curtin University.
# Majoring in International Business and Logistics & Supply Chain Management.

# %% [markdown]
# Module 1
