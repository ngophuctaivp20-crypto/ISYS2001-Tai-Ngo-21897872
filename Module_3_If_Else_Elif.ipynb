# %% [markdown]
# <a href="https://colab.research.google.com/github/ngophuctaivp20-crypto/ISYS2001-Tai-Ngo-21897872/blob/main/Module_3_If_Else_Elif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
