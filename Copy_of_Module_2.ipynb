# %% [markdown]
# <a href="https://colab.research.google.com/github/ngophuctaivp20-crypto/ISYS2001-Tai-Ngo-21897872/blob/main/Copy_of_Module_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_name = input("what is you name ")
print("Name:", user_name)
# Out:
# what is you name Tai
# Name: Tai

# %%
user_name = input("What is your name? ")
theme_color = input("What color would you like for your app theme? (e.g., blue, green, dark) ")
primary_currency = input("What is your primary currency? (e.g., AUD, USD, EUR) ")
main_savings_goal = input("What is one big savings goal you have? (e.g., New Car, Holiday) ")

summary = ("Welcome to your Personal Finance Tracker, " + user_name + "! Your profile is ready. " + \
           "The app will use a " + theme_color + " theme and all amounts will be in " + \
           primary_currency + ". Let's start working towards your goal of saving for a " + \
           main_savings_goal + "!")
print(summary)
# Out:
# What is your name? Tai
# What color would you like for your app theme? (e.g., blue, green, dark) Dark
# What is your primary currency? (e.g., AUD, USD, EUR) USD
# What is one big savings goal you have? (e.g., New Car, Holiday) New Car
# Welcome to your Personal Finance Tracker, Tai! Your profile is ready. The app will use a Dark theme and all amounts will be in USD. Let's start working towards your goal of saving for a New Car!

# %%
import datetime
birth_year=int (input("what's day you were born? "))
current_year = datetime.datetime.now().year
age= current_year - birth_year
print("You are",age,"years old")
# Out:
# what's day you were born? 2006
# You are 20 years old

# %% [markdown]
# Integers: int(...) converts the text you type into a whole number.
#
# Here's why it's needed: input() always returns a string (text), even if you type numbers. So if you type 1998, Python actually gets "1998" — text, not a number. You can't do math with that directly ("1998" + 1 would cause an error).
#
# Wrapping it in int() converts that string into an actual integer, so int("1998") becomes 1998 — now you can use it in calculations, like:

# %% [markdown]
# In programming, float (short for "floating-point number") is a data type used to represent numbers that have a decimal point — i.e., non-integer, real numbers.
